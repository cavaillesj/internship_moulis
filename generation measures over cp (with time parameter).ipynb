# %% [markdown]
# # Generation of the plot

# %%
import time as tm
import colorsys

exec(open("object.py").read(), globals())
exec(open("variability.py").read(), globals())



#exec(open("param.py").read(), globals())
DOSSIER = "plot/measures/coupled/param10/"
A = [0.3, 0.5] 
M = [2., 4., 7., 10.] # [2., 5., 10.]
Strength = [0.001, 0.002, 0.005, 0.008, 0.01]
Alpha = [8, 15, 25]
Beta = [5, 20, 40, 100]
Freq = [0.005, 0.02, 0.1, 0.3, 0.5, 1., 2., 4., 5., 9.]
FinalTime = [10, 40, 100]
Variability = ["Variability_always", "Variability_until", "Variability_only", "Variability_10", "Variability_half", "Speed_collapse", "Viability", "Ratio", "Point"]


#DOSSIER = "plot/measures/coupled/test/"
#DOSSIER = "plot/measures/coupled/param2/"

# %%
def param_study(Number_of_simulation, numbreDePoint, Freq, Param_phy, Init, finalTime, alpha, beta, strength, dt, name):
   # Color = ["blue", "g", "red", "orange", "pink", "black", "magenta", "grey"]
    Param_coupled = {"alpha":alpha,
                     "beta":beta}
    Param_freq = {"p":-1} # going to change
    Param_strength = {"scale":strength}
    Fire_param = {"model": "coupled",
                    "frequence": "bernoulli",
                    "param_freq" : Param_freq,
                    "amplitude": "exponential",
                    "Param_strength" : Param_strength,
                    "Param_coupled" : Param_coupled,
                    "type" : "proportionnal",
                    "coef_W_N" : 5}


    Collapse = np.zeros((numbreDePoint, len(Freq), Number_of_simulation))
    Variability_always = np.zeros_like(Collapse)
    Variability_until = np.zeros_like(Collapse)
    Variability_only = np.zeros_like(Collapse)
    Variability_10 = np.zeros_like(Collapse)
    Collapse_10_b = np.zeros_like(Collapse)
    Collapse_10_m = np.zeros_like(Collapse)
    Variability_half = np.zeros_like(Collapse)
    Speed_collapse = np.zeros_like(Collapse)
    Viability = np.zeros_like(Collapse)
    Ratio = np.zeros_like(Collapse)
    Point = np.zeros_like(Collapse)

    for j in range(numbreDePoint):
        for i, freq in enumerate(Freq):
            Param_freq = {"p":freq}
            Fire_param["param_freq"] = Param_freq
            Variability_half[j,i]
            Speed_collapse[j,i]
            Viability[j,i]
            Collapse[j,i], Variability_always[j,i], Variability_until[j,i], Variability_only[j,i], Variability_10[j,i], Collapse_10_b[j,i], Collapse_10_m[j,i], Variability_half[j,i], Speed_collapse[j,i], Viability[j,i], Ratio[j,i], Point[j,i] = all_measure(Number_of_simulation = Number_of_simulation, mean = False, finalTime = finalTime, Fire_param = Fire_param, dt = dt, Param_phy=Param_phy, Init=Init)
    Compute_variability = {"Variability_always": Variability_always,
                            "Variability_until": Variability_until, 
                            "Variability_only":Variability_only,
                            "Variability_10":Variability_10,
                            "Variability_half":Variability_half,
                            "Speed_collapse":Speed_collapse,
                            "Viability":Viability,
                            "Ratio":Ratio,
                            "Point":Point}


    plt.figure(figsize=(20, 20))
    #plt.suptitle("Variability over collapse for different frequency\nalpha = "+str(alpha)+", beta = "+str(beta), fontsize=20)

    for k, compute_variability in enumerate(Compute_variability.keys()):
        plt.figure(figsize=(12, 8))
        #plt.subplot(2,2,k+1)
        for j in range(numbreDePoint):
            for i, freq in enumerate(Freq):
    #        for i, freq in enumerate(Freq):
                if(j==0):
                    plt.plot(np.nanmean(Collapse[j,i]), np.nanmean(Compute_variability[compute_variability][j,i]), "*", color = Color[i], label=str(freq))
                else:
                    plt.plot(np.nanmean(Collapse[j,i]), np.nanmean(Compute_variability[compute_variability][j,i]), "*", color = Color[i])
        plt.xlim(-0.1, 1.1)
      #  plt.ylim(-0.01, .18)
        plt.xlabel("Collapse", fontsize=15)
        plt.ylabel(compute_variability, fontsize=15)
      #  plt.ylim(ymin, ymax)
        plt.legend()
        
        plt.title(compute_variability+" over collapse for different frequency")
        plt.savefig(name+"_"+compute_variability+".png")
########################
#        plt.show()

    #            plt.title("Variability over collapse for different frequency\nalpha = "+str(alpha)+", beta = "+str(beta), fontsize=20)

# %%
numberColor = len(Freq)
H = [i/numberColor for i in range(numberColor)]
Color = []
for h in H:
    color = colorsys.hls_to_rgb(h, .5, 1)
    Color += [color]

# %%
Number_of_simulation = 50
numbreDePoint = 20

#Freq = [0.005, 0.1, 0.3, 0.5, 1., 3., 5., 9.]
dt = 0.1
#finalTime = 100



nomberFigure = len(FinalTime)*len(A)*len(M)*len(Alpha)*len(Beta)*len(Strength)

c=0
for finalTime in FinalTime:
    for a in A:
        for m in M:
            Param_phy = [a, m]
            Init = [1., Param_phy[1]]
            for strength in Strength:
                for alpha in Alpha:
                    for beta in Beta:
                        name = DOSSIER+"final_time="+str(finalTime)+"a="+str(a)+"_m="+str(m)+"_strength="+str(strength)+"_alpha="+str(alpha)+"_beta="+str(beta)
                        param_study(Number_of_simulation, numbreDePoint, Freq, Param_phy, Init, finalTime, alpha, beta, strength, dt, name)           
                        c+=1
                        print(tm.ctime(), ", Figure ", c*7, "(total ", 7*nomberFigure, ")") # afficher l'heure
# Out:
# C:\Users\jerome\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: Mean of empty slice
# C:\Users\jerome\Anaconda3\lib\site-packages\ipykernel_launcher.py:59: RuntimeWarning: Mean of empty slice
# Thu Mar 28 17:27:21 2019 , Figure  7 (total  10080 )
# Thu Mar 28 17:27:52 2019 , Figure  14 (total  10080 )
# C:\Users\jerome\Anaconda3\lib\site-packages\matplotlib\pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# Thu Mar 28 17:28:23 2019 , Figure  21 (total  10080 )
# Thu Mar 28 17:28:54 2019 , Figure  28 (total  10080 )
# Thu Mar 28 17:29:24 2019 , Figure  35 (total  10080 )
# Thu Mar 28 17:29:55 2019 , Figure  42 (total  10080 )
# Thu Mar 28 17:30:26 2019 , Figure  49 (total  10080 )
# Thu Mar 28 17:30:57 2019 , Figure  56 (total  10080 )
# Thu Mar 28 17:31:28 2019 , Figure  63 (total  10080 )
# Thu Mar 28 17:31:59 2019 , Figure  70 (total  10080 )
# Thu Mar 28 17:32:30 2019 , Figure  77 (total  10080 )
# Thu Mar 28 17:33:01 2019 , Figure  84 (total  10080 )
# Thu Mar 28 17:33:31 2019 , Figure  91 (total  10080 )
# Thu Mar 28 17:34:02 2019 , Figure  98 (total  10080 )
# Thu Mar 28 17:34:33 2019 , Figure  105 (total  10080 )
# Thu Mar 28 17:35:03 2019 , Figure  112 (total  10080 )
# Thu Mar 28 17:35:33 2019 , Figure  119 (total  10080 )
# Thu Mar 28 17:36:05 2019 , Figure  126 (total  10080 )
# Thu Mar 28 17:36:36 2019 , Figure  133 (total  10080 )
# Thu Mar 28 17:37:06 2019 , Figure  140 (total  10080 )
# Thu Mar 28 17:37:36 2019 , Figure  147 (total  10080 )
# Thu Mar 28 17:38:08 2019 , Figure  154 (total  10080 )
# Thu Mar 28 17:38:38 2019 , Figure  161 (total  10080 )
# Thu Mar 28 17:39:09 2019 , Figure  168 (total  10080 )
# Thu Mar 28 17:39:39 2019 , Figure  175 (total  10080 )
# Thu Mar 28 17:40:10 2019 , Figure  182 (total  10080 )
# Thu Mar 28 17:40:40 2019 , Figure  189 (total  10080 )
# Thu Mar 28 17:41:13 2019 , Figure  196 (total  10080 )
# C:\Users\jerome\Anaconda3\lib\site-packages\ipykernel_launcher.py:166: RuntimeWarning: divide by zero encountered in true_divide
# C:\Users\jerome\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2920: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\jerome\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\jerome\Anaconda3\lib\site-packages\ipykernel_launcher.py:143: RuntimeWarning: invalid value encountered in less
# Thu Mar 28 17:41:44 2019 , Figure  203 (total  10080 )
# Thu Mar 28 17:42:14 2019 , Figure  210 (total  10080 )
# Thu Mar 28 17:42:45 2019 , Figure  217 (total  10080 )
# Thu Mar 28 17:43:15 2019 , Figure  224 (total  10080 )
# Thu Mar 28 17:43:45 2019 , Figure  231 (total  10080 )
# Thu Mar 28 17:44:16 2019 , Figure  238 (total  10080 )
# Thu Mar 28 17:44:49 2019 , Figure  245 (total  10080 )
# Thu Mar 28 17:45:20 2019 , Figure  252 (total  10080 )
# Thu Mar 28 17:45:50 2019 , Figure  259 (total  10080 )
# Thu Mar 28 17:46:20 2019 , Figure  266 (total  10080 )
# Thu Mar 28 17:46:51 2019 , Figure  273 (total  10080 )
# Thu Mar 28 17:47:21 2019 , Figure  280 (total  10080 )
# Thu Mar 28 17:47:51 2019 , Figure  287 (total  10080 )
# Thu Mar 28 17:48:22 2019 , Figure  294 (total  10080 )
# Thu Mar 28 17:48:56 2019 , Figure  301 (total  10080 )
# Thu Mar 28 17:49:26 2019 , Figure  308 (total  10080 )
# Thu Mar 28 17:49:57 2019 , Figure  315 (total  10080 )
# Thu Mar 28 17:50:28 2019 , Figure  322 (total  10080 )
# Thu Mar 28 17:50:58 2019 , Figure  329 (total  10080 )
# Thu Mar 28 17:51:29 2019 , Figure  336 (total  10080 )
# Thu Mar 28 17:51:59 2019 , Figure  343 (total  10080 )
# Thu Mar 28 17:52:29 2019 , Figure  350 (total  10080 )
# Thu Mar 28 17:53:00 2019 , Figure  357 (total  10080 )
# Thu Mar 28 17:53:32 2019 , Figure  364 (total  10080 )
# Thu Mar 28 17:54:05 2019 , Figure  371 (total  10080 )
# Thu Mar 28 17:54:41 2019 , Figure  378 (total  10080 )
# Thu Mar 28 17:55:11 2019 , Figure  385 (total  10080 )
# Thu Mar 28 17:55:42 2019 , Figure  392 (total  10080 )
# Thu Mar 28 17:56:12 2019 , Figure  399 (total  10080 )
# Thu Mar 28 17:56:43 2019 , Figure  406 (total  10080 )
# Thu Mar 28 17:57:14 2019 , Figure  413 (total  10080 )
# Thu Mar 28 17:57:44 2019 , Figure  420 (total  10080 )
# Thu Mar 28 17:58:15 2019 , Figure  427 (total  10080 )
# Thu Mar 28 17:58:45 2019 , Figure  434 (total  10080 )
# Thu Mar 28 17:59:15 2019 , Figure  441 (total  10080 )
# Thu Mar 28 17:59:46 2019 , Figure  448 (total  10080 )
# Thu Mar 28 18:00:16 2019 , Figure  455 (total  10080 )
# Thu Mar 28 18:00:47 2019 , Figure  462 (total  10080 )
# Thu Mar 28 18:01:17 2019 , Figure  469 (total  10080 )
# Thu Mar 28 18:01:54 2019 , Figure  476 (total  10080 )
# Thu Mar 28 18:02:24 2019 , Figure  483 (total  10080 )
# Thu Mar 28 18:02:54 2019 , Figure  490 (total  10080 )
# Thu Mar 28 18:03:25 2019 , Figure  497 (total  10080 )
# Thu Mar 28 18:03:55 2019 , Figure  504 (total  10080 )
# Thu Mar 28 18:04:26 2019 , Figure  511 (total  10080 )
# Thu Mar 28 18:04:56 2019 , Figure  518 (total  10080 )
# Thu Mar 28 18:05:26 2019 , Figure  525 (total  10080 )
# Thu Mar 28 18:05:57 2019 , Figure  532 (total  10080 )
# Thu Mar 28 18:06:28 2019 , Figure  539 (total  10080 )
# Thu Mar 28 18:06:58 2019 , Figure  546 (total  10080 )
# Thu Mar 28 18:07:29 2019 , Figure  553 (total  10080 )
# Thu Mar 28 18:07:59 2019 , Figure  560 (total  10080 )
# Thu Mar 28 18:08:30 2019 , Figure  567 (total  10080 )
# Thu Mar 28 18:09:00 2019 , Figure  574 (total  10080 )
# Thu Mar 28 18:09:31 2019 , Figure  581 (total  10080 )
# Thu Mar 28 18:10:09 2019 , Figure  588 (total  10080 )
# Thu Mar 28 18:10:40 2019 , Figure  595 (total  10080 )
# Thu Mar 28 18:11:10 2019 , Figure  602 (total  10080 )
# Thu Mar 28 18:11:40 2019 , Figure  609 (total  10080 )
# Thu Mar 28 18:12:11 2019 , Figure  616 (total  10080 )
# Thu Mar 28 18:12:42 2019 , Figure  623 (total  10080 )
# Thu Mar 28 18:13:12 2019 , Figure  630 (total  10080 )
# Thu Mar 28 18:13:43 2019 , Figure  637 (total  10080 )
# Thu Mar 28 18:14:13 2019 , Figure  644 (total  10080 )
# Thu Mar 28 18:14:44 2019 , Figure  651 (total  10080 )
# Thu Mar 28 18:15:15 2019 , Figure  658 (total  10080 )
# Thu Mar 28 18:15:46 2019 , Figure  665 (total  10080 )
# Thu Mar 28 18:16:17 2019 , Figure  672 (total  10080 )
# Thu Mar 28 18:16:48 2019 , Figure  679 (total  10080 )
# Thu Mar 28 18:17:18 2019 , Figure  686 (total  10080 )
# Thu Mar 28 18:17:49 2019 , Figure  693 (total  10080 )
# Thu Mar 28 18:18:19 2019 , Figure  700 (total  10080 )
# Thu Mar 28 18:18:50 2019 , Figure  707 (total  10080 )
# Thu Mar 28 18:19:21 2019 , Figure  714 (total  10080 )
# Thu Mar 28 18:19:51 2019 , Figure  721 (total  10080 )
# Thu Mar 28 18:20:22 2019 , Figure  728 (total  10080 )
# Thu Mar 28 18:21:02 2019 , Figure  735 (total  10080 )
# Thu Mar 28 18:21:33 2019 , Figure  742 (total  10080 )
# Thu Mar 28 18:22:04 2019 , Figure  749 (total  10080 )
# Thu Mar 28 18:22:35 2019 , Figure  756 (total  10080 )
# Thu Mar 28 18:23:06 2019 , Figure  763 (total  10080 )
# Thu Mar 28 18:23:37 2019 , Figure  770 (total  10080 )
# Thu Mar 28 18:24:07 2019 , Figure  777 (total  10080 )
# Thu Mar 28 18:24:38 2019 , Figure  784 (total  10080 )
# Thu Mar 28 18:25:08 2019 , Figure  791 (total  10080 )
# Thu Mar 28 18:25:39 2019 , Figure  798 (total  10080 )
# Thu Mar 28 18:26:10 2019 , Figure  805 (total  10080 )
# Thu Mar 28 18:26:41 2019 , Figure  812 (total  10080 )
# Thu Mar 28 18:27:12 2019 , Figure  819 (total  10080 )
# Thu Mar 28 18:27:43 2019 , Figure  826 (total  10080 )
# Thu Mar 28 18:28:14 2019 , Figure  833 (total  10080 )
# Thu Mar 28 18:28:45 2019 , Figure  840 (total  10080 )
# Thu Mar 28 18:29:16 2019 , Figure  847 (total  10080 )
# Thu Mar 28 18:29:47 2019 , Figure  854 (total  10080 )
# Thu Mar 28 18:30:18 2019 , Figure  861 (total  10080 )
# Thu Mar 28 18:30:49 2019 , Figure  868 (total  10080 )
# Thu Mar 28 18:31:21 2019 , Figure  875 (total  10080 )
# Thu Mar 28 18:31:52 2019 , Figure  882 (total  10080 )
# Thu Mar 28 18:32:23 2019 , Figure  889 (total  10080 )
# Thu Mar 28 18:32:54 2019 , Figure  896 (total  10080 )
# Thu Mar 28 18:33:26 2019 , Figure  903 (total  10080 )
# Thu Mar 28 18:33:57 2019 , Figure  910 (total  10080 )
# Thu Mar 28 18:34:40 2019 , Figure  917 (total  10080 )
# Thu Mar 28 18:35:11 2019 , Figure  924 (total  10080 )
# Thu Mar 28 18:35:43 2019 , Figure  931 (total  10080 )
# Thu Mar 28 18:36:14 2019 , Figure  938 (total  10080 )
# Thu Mar 28 18:36:45 2019 , Figure  945 (total  10080 )
# Thu Mar 28 18:37:16 2019 , Figure  952 (total  10080 )
# Thu Mar 28 18:37:47 2019 , Figure  959 (total  10080 )
# Thu Mar 28 18:38:18 2019 , Figure  966 (total  10080 )
# Thu Mar 28 18:38:49 2019 , Figure  973 (total  10080 )
# Thu Mar 28 18:39:21 2019 , Figure  980 (total  10080 )
# Thu Mar 28 18:39:52 2019 , Figure  987 (total  10080 )
# Thu Mar 28 18:40:23 2019 , Figure  994 (total  10080 )
# Thu Mar 28 18:40:55 2019 , Figure  1001 (total  10080 )
# Thu Mar 28 18:41:26 2019 , Figure  1008 (total  10080 )
# Thu Mar 28 18:41:58 2019 , Figure  1015 (total  10080 )
# Thu Mar 28 18:42:29 2019 , Figure  1022 (total  10080 )
# Thu Mar 28 18:43:00 2019 , Figure  1029 (total  10080 )
# Thu Mar 28 18:43:31 2019 , Figure  1036 (total  10080 )
# Thu Mar 28 18:44:03 2019 , Figure  1043 (total  10080 )
# Thu Mar 28 18:44:34 2019 , Figure  1050 (total  10080 )
# Thu Mar 28 18:45:05 2019 , Figure  1057 (total  10080 )
# Thu Mar 28 18:45:37 2019 , Figure  1064 (total  10080 )
# Thu Mar 28 18:46:08 2019 , Figure  1071 (total  10080 )
# Thu Mar 28 18:46:40 2019 , Figure  1078 (total  10080 )
# Thu Mar 28 18:47:12 2019 , Figure  1085 (total  10080 )
# Thu Mar 28 18:47:44 2019 , Figure  1092 (total  10080 )
# Thu Mar 28 18:48:15 2019 , Figure  1099 (total  10080 )
# Thu Mar 28 18:48:46 2019 , Figure  1106 (total  10080 )
# Thu Mar 28 18:49:18 2019 , Figure  1113 (total  10080 )
# Thu Mar 28 18:49:49 2019 , Figure  1120 (total  10080 )
# Thu Mar 28 18:50:21 2019 , Figure  1127 (total  10080 )
# Thu Mar 28 18:50:52 2019 , Figure  1134 (total  10080 )
# Thu Mar 28 18:51:39 2019 , Figure  1141 (total  10080 )
# Thu Mar 28 18:52:11 2019 , Figure  1148 (total  10080 )
# Thu Mar 28 18:52:43 2019 , Figure  1155 (total  10080 )
# Thu Mar 28 18:53:15 2019 , Figure  1162 (total  10080 )
# Thu Mar 28 18:53:47 2019 , Figure  1169 (total  10080 )
# Thu Mar 28 18:54:18 2019 , Figure  1176 (total  10080 )
# Thu Mar 28 18:54:49 2019 , Figure  1183 (total  10080 )
# Thu Mar 28 18:55:21 2019 , Figure  1190 (total  10080 )
# Thu Mar 28 18:55:53 2019 , Figure  1197 (total  10080 )
# Thu Mar 28 18:56:24 2019 , Figure  1204 (total  10080 )
# Thu Mar 28 18:56:55 2019 , Figure  1211 (total  10080 )
# Thu Mar 28 18:57:27 2019 , Figure  1218 (total  10080 )
# Thu Mar 28 18:57:58 2019 , Figure  1225 (total  10080 )
# Thu Mar 28 18:58:30 2019 , Figure  1232 (total  10080 )
# Thu Mar 28 18:59:01 2019 , Figure  1239 (total  10080 )
# Thu Mar 28 18:59:33 2019 , Figure  1246 (total  10080 )
# Thu Mar 28 19:00:05 2019 , Figure  1253 (total  10080 )
# Thu Mar 28 19:00:36 2019 , Figure  1260 (total  10080 )
# Thu Mar 28 19:01:08 2019 , Figure  1267 (total  10080 )
# Thu Mar 28 19:01:39 2019 , Figure  1274 (total  10080 )
# Thu Mar 28 19:02:11 2019 , Figure  1281 (total  10080 )
# Thu Mar 28 19:02:41 2019 , Figure  1288 (total  10080 )
# Thu Mar 28 19:03:13 2019 , Figure  1295 (total  10080 )
# Thu Mar 28 19:03:44 2019 , Figure  1302 (total  10080 )
# Thu Mar 28 19:04:15 2019 , Figure  1309 (total  10080 )
# Thu Mar 28 19:04:46 2019 , Figure  1316 (total  10080 )
# Thu Mar 28 19:05:18 2019 , Figure  1323 (total  10080 )
# Thu Mar 28 19:05:49 2019 , Figure  1330 (total  10080 )
# Thu Mar 28 19:06:21 2019 , Figure  1337 (total  10080 )
# Thu Mar 28 19:06:52 2019 , Figure  1344 (total  10080 )
# Thu Mar 28 19:07:23 2019 , Figure  1351 (total  10080 )
# Thu Mar 28 19:07:55 2019 , Figure  1358 (total  10080 )
# Thu Mar 28 19:08:25 2019 , Figure  1365 (total  10080 )
# Thu Mar 28 19:08:56 2019 , Figure  1372 (total  10080 )
# Thu Mar 28 19:09:28 2019 , Figure  1379 (total  10080 )
# Thu Mar 28 19:09:59 2019 , Figure  1386 (total  10080 )
# Thu Mar 28 19:10:30 2019 , Figure  1393 (total  10080 )
# Thu Mar 28 19:11:01 2019 , Figure  1400 (total  10080 )
# Thu Mar 28 19:11:32 2019 , Figure  1407 (total  10080 )
# Thu Mar 28 19:12:03 2019 , Figure  1414 (total  10080 )
# Thu Mar 28 19:13:03 2019 , Figure  1421 (total  10080 )
# Thu Mar 28 19:13:34 2019 , Figure  1428 (total  10080 )
# Thu Mar 28 19:14:06 2019 , Figure  1435 (total  10080 )
# Thu Mar 28 19:14:37 2019 , Figure  1442 (total  10080 )
# Thu Mar 28 19:15:08 2019 , Figure  1449 (total  10080 )
# Thu Mar 28 19:15:39 2019 , Figure  1456 (total  10080 )
# Thu Mar 28 19:16:10 2019 , Figure  1463 (total  10080 )
# Thu Mar 28 19:16:42 2019 , Figure  1470 (total  10080 )
# Thu Mar 28 19:17:13 2019 , Figure  1477 (total  10080 )
# Thu Mar 28 19:17:45 2019 , Figure  1484 (total  10080 )
# Thu Mar 28 19:18:16 2019 , Figure  1491 (total  10080 )
# Thu Mar 28 19:18:47 2019 , Figure  1498 (total  10080 )
# Thu Mar 28 19:19:18 2019 , Figure  1505 (total  10080 )
# Thu Mar 28 19:19:50 2019 , Figure  1512 (total  10080 )
# Thu Mar 28 19:20:21 2019 , Figure  1519 (total  10080 )
# Thu Mar 28 19:20:52 2019 , Figure  1526 (total  10080 )
# Thu Mar 28 19:21:24 2019 , Figure  1533 (total  10080 )
# Thu Mar 28 19:21:55 2019 , Figure  1540 (total  10080 )
# Thu Mar 28 19:22:27 2019 , Figure  1547 (total  10080 )
# Thu Mar 28 19:22:58 2019 , Figure  1554 (total  10080 )
# Thu Mar 28 19:23:29 2019 , Figure  1561 (total  10080 )
# Thu Mar 28 19:24:00 2019 , Figure  1568 (total  10080 )
# Thu Mar 28 19:24:31 2019 , Figure  1575 (total  10080 )
# Thu Mar 28 19:25:03 2019 , Figure  1582 (total  10080 )
# Thu Mar 28 19:25:34 2019 , Figure  1589 (total  10080 )
# Thu Mar 28 19:26:05 2019 , Figure  1596 (total  10080 )
# Thu Mar 28 19:26:37 2019 , Figure  1603 (total  10080 )
# Thu Mar 28 19:27:08 2019 , Figure  1610 (total  10080 )
# Thu Mar 28 19:27:40 2019 , Figure  1617 (total  10080 )
# Thu Mar 28 19:28:11 2019 , Figure  1624 (total  10080 )
# Thu Mar 28 19:28:42 2019 , Figure  1631 (total  10080 )
# Thu Mar 28 19:29:14 2019 , Figure  1638 (total  10080 )
# Thu Mar 28 19:29:46 2019 , Figure  1645 (total  10080 )
# Thu Mar 28 19:30:17 2019 , Figure  1652 (total  10080 )
# Thu Mar 28 19:30:49 2019 , Figure  1659 (total  10080 )
# Thu Mar 28 19:31:20 2019 , Figure  1666 (total  10080 )
# Thu Mar 28 19:31:51 2019 , Figure  1673 (total  10080 )
# Thu Mar 28 19:32:22 2019 , Figure  1680 (total  10080 )
# Thu Mar 28 19:32:53 2019 , Figure  1687 (total  10080 )
# Thu Mar 28 19:33:23 2019 , Figure  1694 (total  10080 )
# Thu Mar 28 19:33:54 2019 , Figure  1701 (total  10080 )
# Thu Mar 28 19:34:25 2019 , Figure  1708 (total  10080 )
# Thu Mar 28 19:34:55 2019 , Figure  1715 (total  10080 )
# Thu Mar 28 19:35:26 2019 , Figure  1722 (total  10080 )
# Thu Mar 28 19:35:57 2019 , Figure  1729 (total  10080 )
# Thu Mar 28 19:36:28 2019 , Figure  1736 (total  10080 )
# Thu Mar 28 19:36:58 2019 , Figure  1743 (total  10080 )
# Thu Mar 28 19:37:29 2019 , Figure  1750 (total  10080 )
# Thu Mar 28 19:38:00 2019 , Figure  1757 (total  10080 )
# Thu Mar 28 19:38:31 2019 , Figure  1764 (total  10080 )
# Thu Mar 28 19:43:17 2019 , Figure  1771 (total  10080 )
# Thu Mar 28 19:43:49 2019 , Figure  1778 (total  10080 )
# Thu Mar 28 19:44:20 2019 , Figure  1785 (total  10080 )
# Thu Mar 28 19:44:51 2019 , Figure  1792 (total  10080 )
# Thu Mar 28 19:45:22 2019 , Figure  1799 (total  10080 )
# Thu Mar 28 19:45:53 2019 , Figure  1806 (total  10080 )
# Thu Mar 28 19:46:25 2019 , Figure  1813 (total  10080 )
# Thu Mar 28 19:47:06 2019 , Figure  1820 (total  10080 )
# Thu Mar 28 19:47:38 2019 , Figure  1827 (total  10080 )
# Thu Mar 28 19:48:19 2019 , Figure  1834 (total  10080 )
# Thu Mar 28 19:48:53 2019 , Figure  1841 (total  10080 )
# Thu Mar 28 19:49:42 2019 , Figure  1848 (total  10080 )
# Thu Mar 28 19:50:13 2019 , Figure  1855 (total  10080 )
# Thu Mar 28 19:50:45 2019 , Figure  1862 (total  10080 )
# Thu Mar 28 19:51:16 2019 , Figure  1869 (total  10080 )
# Thu Mar 28 19:52:15 2019 , Figure  1876 (total  10080 )
# Thu Mar 28 19:52:53 2019 , Figure  1883 (total  10080 )
# Thu Mar 28 19:53:25 2019 , Figure  1890 (total  10080 )
# Thu Mar 28 19:54:07 2019 , Figure  1897 (total  10080 )
# Thu Mar 28 19:54:38 2019 , Figure  1904 (total  10080 )
# Thu Mar 28 19:55:26 2019 , Figure  1911 (total  10080 )
# Thu Mar 28 19:55:58 2019 , Figure  1918 (total  10080 )
# Thu Mar 28 19:56:30 2019 , Figure  1925 (total  10080 )
# Thu Mar 28 19:57:23 2019 , Figure  1932 (total  10080 )
# Thu Mar 28 19:58:03 2019 , Figure  1939 (total  10080 )
# Thu Mar 28 19:58:35 2019 , Figure  1946 (total  10080 )
# Thu Mar 28 19:59:08 2019 , Figure  1953 (total  10080 )
# Thu Mar 28 19:59:48 2019 , Figure  1960 (total  10080 )
# Thu Mar 28 20:00:22 2019 , Figure  1967 (total  10080 )
# Thu Mar 28 20:00:53 2019 , Figure  1974 (total  10080 )
# Thu Mar 28 20:01:25 2019 , Figure  1981 (total  10080 )
# Thu Mar 28 20:01:57 2019 , Figure  1988 (total  10080 )
# Thu Mar 28 20:02:29 2019 , Figure  1995 (total  10080 )
# Thu Mar 28 20:03:09 2019 , Figure  2002 (total  10080 )
# Thu Mar 28 20:03:41 2019 , Figure  2009 (total  10080 )
# Thu Mar 28 20:04:13 2019 , Figure  2016 (total  10080 )
# Thu Mar 28 20:04:45 2019 , Figure  2023 (total  10080 )
# Thu Mar 28 20:05:28 2019 , Figure  2030 (total  10080 )
# Thu Mar 28 20:05:59 2019 , Figure  2037 (total  10080 )
# Thu Mar 28 20:06:30 2019 , Figure  2044 (total  10080 )
# Thu Mar 28 20:07:03 2019 , Figure  2051 (total  10080 )
# Thu Mar 28 20:07:34 2019 , Figure  2058 (total  10080 )
# Thu Mar 28 20:08:06 2019 , Figure  2065 (total  10080 )
# Thu Mar 28 20:08:37 2019 , Figure  2072 (total  10080 )
# Thu Mar 28 20:09:15 2019 , Figure  2079 (total  10080 )
# Thu Mar 28 20:09:48 2019 , Figure  2086 (total  10080 )
# Thu Mar 28 20:10:19 2019 , Figure  2093 (total  10080 )
# Thu Mar 28 20:10:51 2019 , Figure  2100 (total  10080 )
# Thu Mar 28 20:11:23 2019 , Figure  2107 (total  10080 )
# Thu Mar 28 20:11:55 2019 , Figure  2114 (total  10080 )
# Thu Mar 28 20:12:26 2019 , Figure  2121 (total  10080 )
# Thu Mar 28 20:12:57 2019 , Figure  2128 (total  10080 )
# Thu Mar 28 20:13:28 2019 , Figure  2135 (total  10080 )
# Thu Mar 28 20:13:59 2019 , Figure  2142 (total  10080 )
# Thu Mar 28 20:14:33 2019 , Figure  2149 (total  10080 )
# Thu Mar 28 20:15:04 2019 , Figure  2156 (total  10080 )
# Thu Mar 28 20:15:36 2019 , Figure  2163 (total  10080 )
# Thu Mar 28 20:16:07 2019 , Figure  2170 (total  10080 )
# Thu Mar 28 20:16:38 2019 , Figure  2177 (total  10080 )
# Thu Mar 28 20:17:10 2019 , Figure  2184 (total  10080 )
# Thu Mar 28 20:17:40 2019 , Figure  2191 (total  10080 )
# Thu Mar 28 20:18:11 2019 , Figure  2198 (total  10080 )
# Thu Mar 28 22:05:34 2019 , Figure  2205 (total  10080 )
# Thu Mar 28 22:06:07 2019 , Figure  2212 (total  10080 )
# Thu Mar 28 22:06:39 2019 , Figure  2219 (total  10080 )
# Thu Mar 28 22:07:11 2019 , Figure  2226 (total  10080 )
# Thu Mar 28 22:07:43 2019 , Figure  2233 (total  10080 )
# Thu Mar 28 22:08:15 2019 , Figure  2240 (total  10080 )
# Thu Mar 28 22:08:46 2019 , Figure  2247 (total  10080 )
# Thu Mar 28 22:09:18 2019 , Figure  2254 (total  10080 )
# Thu Mar 28 22:09:49 2019 , Figure  2261 (total  10080 )
# Thu Mar 28 22:10:21 2019 , Figure  2268 (total  10080 )
# Thu Mar 28 22:10:53 2019 , Figure  2275 (total  10080 )
# Thu Mar 28 22:11:26 2019 , Figure  2282 (total  10080 )
# Thu Mar 28 22:11:57 2019 , Figure  2289 (total  10080 )
# Thu Mar 28 22:12:30 2019 , Figure  2296 (total  10080 )
# Thu Mar 28 22:13:07 2019 , Figure  2303 (total  10080 )
# Thu Mar 28 22:13:43 2019 , Figure  2310 (total  10080 )
# Thu Mar 28 22:14:15 2019 , Figure  2317 (total  10080 )
# Thu Mar 28 22:15:06 2019 , Figure  2324 (total  10080 )
# Thu Mar 28 22:15:38 2019 , Figure  2331 (total  10080 )
# Thu Mar 28 22:16:17 2019 , Figure  2338 (total  10080 )
# Thu Mar 28 22:16:49 2019 , Figure  2345 (total  10080 )
# Thu Mar 28 22:17:30 2019 , Figure  2352 (total  10080 )
# Thu Mar 28 22:18:02 2019 , Figure  2359 (total  10080 )
# Thu Mar 28 22:18:33 2019 , Figure  2366 (total  10080 )
# Thu Mar 28 22:19:14 2019 , Figure  2373 (total  10080 )
# Thu Mar 28 22:19:47 2019 , Figure  2380 (total  10080 )
# Thu Mar 28 22:20:20 2019 , Figure  2387 (total  10080 )
# Thu Mar 28 22:20:54 2019 , Figure  2394 (total  10080 )
# Thu Mar 28 22:21:26 2019 , Figure  2401 (total  10080 )
# Thu Mar 28 22:22:08 2019 , Figure  2408 (total  10080 )
# Thu Mar 28 22:22:40 2019 , Figure  2415 (total  10080 )
# Thu Mar 28 22:23:15 2019 , Figure  2422 (total  10080 )
# Thu Mar 28 22:23:52 2019 , Figure  2429 (total  10080 )
# Thu Mar 28 22:24:24 2019 , Figure  2436 (total  10080 )
# Thu Mar 28 22:24:59 2019 , Figure  2443 (total  10080 )
# Thu Mar 28 22:25:31 2019 , Figure  2450 (total  10080 )
# Thu Mar 28 22:26:03 2019 , Figure  2457 (total  10080 )
# Thu Mar 28 22:26:34 2019 , Figure  2464 (total  10080 )
# Thu Mar 28 22:27:07 2019 , Figure  2471 (total  10080 )
# Thu Mar 28 22:27:39 2019 , Figure  2478 (total  10080 )
# Thu Mar 28 22:28:20 2019 , Figure  2485 (total  10080 )
# Thu Mar 28 22:28:52 2019 , Figure  2492 (total  10080 )
# Thu Mar 28 22:29:24 2019 , Figure  2499 (total  10080 )
# Thu Mar 28 22:29:56 2019 , Figure  2506 (total  10080 )
# Thu Mar 28 22:30:36 2019 , Figure  2513 (total  10080 )
# Thu Mar 28 22:31:15 2019 , Figure  2520 (total  10080 )
# Thu Mar 28 22:31:47 2019 , Figure  2527 (total  10080 )
# Thu Mar 28 22:32:18 2019 , Figure  2534 (total  10080 )
# Thu Mar 28 22:32:52 2019 , Figure  2541 (total  10080 )
# Thu Mar 28 22:33:24 2019 , Figure  2548 (total  10080 )
# Thu Mar 28 22:33:56 2019 , Figure  2555 (total  10080 )
# Thu Mar 28 22:34:27 2019 , Figure  2562 (total  10080 )
# Thu Mar 28 22:34:59 2019 , Figure  2569 (total  10080 )
# Thu Mar 28 22:35:32 2019 , Figure  2576 (total  10080 )
# Thu Mar 28 22:36:05 2019 , Figure  2583 (total  10080 )
# Thu Mar 28 22:36:37 2019 , Figure  2590 (total  10080 )
# Thu Mar 28 22:37:08 2019 , Figure  2597 (total  10080 )
# Thu Mar 28 22:37:43 2019 , Figure  2604 (total  10080 )
# Thu Mar 28 22:38:22 2019 , Figure  2611 (total  10080 )
# Thu Mar 28 22:39:00 2019 , Figure  2618 (total  10080 )
# Thu Mar 28 22:39:32 2019 , Figure  2625 (total  10080 )
# Thu Mar 28 22:40:03 2019 , Figure  2632 (total  10080 )
# Thu Mar 28 22:40:35 2019 , Figure  2639 (total  10080 )
# Thu Mar 28 22:41:14 2019 , Figure  2646 (total  10080 )
# Thu Mar 28 22:41:49 2019 , Figure  2653 (total  10080 )
# Thu Mar 28 22:42:23 2019 , Figure  2660 (total  10080 )
# Thu Mar 28 22:42:59 2019 , Figure  2667 (total  10080 )
# Thu Mar 28 22:43:30 2019 , Figure  2674 (total  10080 )
# Thu Mar 28 22:44:02 2019 , Figure  2681 (total  10080 )
# Thu Mar 28 22:44:34 2019 , Figure  2688 (total  10080 )
# Thu Mar 28 22:45:05 2019 , Figure  2695 (total  10080 )
# Thu Mar 28 22:45:42 2019 , Figure  2702 (total  10080 )
# Thu Mar 28 22:46:14 2019 , Figure  2709 (total  10080 )
# Thu Mar 28 22:46:46 2019 , Figure  2716 (total  10080 )
# Thu Mar 28 22:47:23 2019 , Figure  2723 (total  10080 )
# Thu Mar 28 22:47:55 2019 , Figure  2730 (total  10080 )
# Thu Mar 28 22:48:27 2019 , Figure  2737 (total  10080 )
# Thu Mar 28 22:48:58 2019 , Figure  2744 (total  10080 )
